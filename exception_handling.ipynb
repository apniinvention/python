# %% [markdown]
# #Python Exception Handling

# %% [markdown]
# ####Error in Python can be of two types i.e.
# **Syntax errors** and **Exceptions**.
# * **Errors** are the problems in a program due to which the program will stop the execution.
# * **Exceptions** are raised when some internal events occur which changes the normal flow of the program.

# %% [markdown]
# ###How try() works?
#
#
# * First, the try clause is executed i.e. the code between try and except clause.
# *If there is no exception, then only the try clause will run, except the clause is finished.
# *If any exception occurs, the try clause will be skipped and except clause will run.
# *If any exception occurs, but the except clause within the code doesn’t handle it, it is passed on to the outer try statements.
# *If the exception is left unhandled, then the execution stops.
# *A try statement can have more than one except clause
#
# Below are some common exceptions ::
#
# ![Exception_with_description.png](data:image/png;base64,...)

# %% [markdown]
# 1. Error in Python

# %%
#Example of Error in Python
a = 4
if a % 2 == 0 
  print("Even Number")
# Out:
#   File "<ipython-input-4-40dbbf6ef7b1>", line 3
#     if a % 2 == 0
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# 2. Exception
#
# Exceptions are raised when the program is syntactically correct, but the code resulted in an error. This error does not stop the execution of the program, however, it changes the normal flow of the program.

# %%
# Example of Exception : ZeroDivisionError
a = 100

print(a/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-ee9dc2952b62> in <module>()
#       2 a = 100
#       3
# ----> 4 print(a/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# In the above example raised the ZeroDivisionError as we are trying to divide a number by 0.
#
# Note: Exception is the base class for all the exceptions in Python. Below is the chart for your reference
# ![Exception.png](data:image/png;base64,...)

# %% [markdown]
# Let's see how we can handle the exception gracefully
#
# By handling the exception means either we can gracefully termincate the execution by raising the error with proper message or we can write a second level execution as well (not much recomended)

# %%
# Example of a simple exception
# type : Index out of bound

a = [1,2,3]

try :
  print(a[4])
except :
  print(" Error occured because of your logic")
# Out:
#  Error occured because of your logic

# %% [markdown]
# In the above example, within the try block we can write our own logic and based on the logic we can raise an exception related to our logic

# %% [markdown]
# Now, Lets Catch the specific Exception
#
# Below is the syntax
# ---------------------
#
# **try**:
#   #statement
#
# **Except IndexError:**
#   #statement
#
# **Except ValueError**:
#   #statement

# %%
#Example of catching specific Exception
a = 100

try:
  print(a/0)
except ZeroDivisionError:
  print("ZeroDivisionError Occurred and Handled")
# Out:
# ZeroDivisionError Occurred and Handled

# %% [markdown]
# We can also add ELSE cluase after except

# %%
# Example of else cluase with try & except
a = 100

try:
  if a != 100:
    print(a/0)
except ZeroDivisionError:
  print("ZeroDivisionError Occurred and Handled")
else:
  print("Exception didnt occured")
# Out:
# Exception didnt occured

# %% [markdown]
# Finally Keyword

# %%
a = 100

try:
  if a != 100:
    print(a/0)
except ZeroDivisionError:
  print("ZeroDivisionError Occurred and Handled")
else:
  print("Exception didnt occured")
finally:
  print("This will always executed")
# Out:
# Exception didnt occured
# This will always executed

# %% [markdown]
# Let's Raise Exception instead of printing

# %%
a = 100
if a > 10:
  raise Exception("Exception Raised")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-15-45b0b30797f0> in <module>()
#       1 a = 100
#       2 if a > 10:
# ----> 3   raise Exception("Exception Raised")
#
# Exception: Exception Raised

# %%
a = 100

try:
    print(a/0)
except :
  print("ZeroDivisionError Occurred and Handled")
  raise  # because of this line, we are getting traceback exception or the default exception as well
# Out:
# ZeroDivisionError Occurred and Handled
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-21-effca406a365> in <module>()
#       2
#       3 try:
# ----> 4     print(a/0)
#       5 except :
#       6   print("ZeroDivisionError Occurred and Handled")
#
# ZeroDivisionError: division by zero

# %%
print(dir(locals()['__builtins__']))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %% [markdown]
# Below are some sample exception from the above list

# %%
import module_does_not_exist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-fc2ca198aad4> in <module>()
# ----> 1 import module_does_not_exist
#
# ModuleNotFoundError: No module named 'module_does_not_exist'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
array = { 'a':1, 'b':2 }
print (array['c'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-aeef2a8643b7> in <module>()
#       1 array = { 'a':1, 'b':2 }
# ----> 2 print (array['c'])
#
# KeyError: 'c'

# %% [markdown]
# except as Exception

# %%
def catch():
     try:
         array = { 'a':1, 'b':2 }
         print(10/0)
        #  print (array['c'])
     except Exception as e:
         print ("In My Exception --> ",e.with_traceback,e.args)
         
 
catch()
# Out:
# In My Exception -->  <built-in method with_traceback of ZeroDivisionError object at 0x7f537189d2f0> ('division by zero',)

# %% [markdown]
# ####User Defined Exceptio

# %%
# A python program to create user-defined exception
# class MyError is derived from super class Exception
class MyError(Exception):
 
    # Constructor or Initializer
    def __init__(self, value):
        self.value = value
 
    # __str__ is to print() the value
    def __str__(self):
        return(repr(self.value))
 
 
try:
    raise(MyError(3*2))
 
# Value of Exception is stored in error
except MyError as error:
    print('A New Exception occurred: ', error.value)
# Out:
# A New Exception occurred:  6
